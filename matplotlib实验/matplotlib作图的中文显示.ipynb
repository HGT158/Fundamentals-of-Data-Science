# %% [markdown]
# 利用 Matplotlib 绘图时，有时需要在图中进行一些标注，可能会涉及一些符号，尤其是中文。

# %%
import matplotlib.pyplot as plt 
import numpy as np

## 在 Jupyter Notebook 中显示图像还需要添加以下代码
# %matplotlib inline 
# %config InlineBackend.figure_format = "retina" # 在屏幕上显示高清图片

# %%
#绘制图形数据
t = np.arange(0,10,0.05) 
x = np.sin(t) 
y = np.cos(t)

# %%
## 定义一个图像窗口大小
plt.figure(figsize=(8,5)) 
## 按 x、y 坐标绘制图形
plt.plot(t,x,"r-*",label='sin') #绘制 sin 函数图像
plt.plot(t,y,"b-o",label='cos') #绘制 cos 函数图像
#plt.plot(x,y,"g-.",label='sin+cos') #绘制 cos 函数图像
#将 x、y 两条曲线之间的的部分用 green 颜色填充
plt.fill_between(t, x, y, color='green', alpha=0.5) 
plt.axis("equal") #保证饼图是正圆，否则会有一点角度偏斜
plt.xlabel("x-横坐标") 
plt.ylabel("y-纵坐标") 
plt.title("三角函数") 
##显示图例
label=["sin",'cos'] 
plt.legend(label, loc='upper right') 
##保存图像
plt.savefig('./test2.jpg') #将图片保存在当前的目录下
# Out:
# D:\app-soft\anaconda\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 19977 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\app-soft\anaconda\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 35282 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\app-soft\anaconda\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 20989 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\app-soft\anaconda\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 25968 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\app-soft\anaconda\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 27178 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
plt.rcParams['font.sans-serif']=['SimHei'] #用来正常显示中文标签
plt.rcParams['axes.unicode_minus']=False #用来正常显示负号

## 定义一个图像窗口大小
plt.figure(figsize=(8,5)) 
## 按 x、y 坐标绘制图形
plt.plot(t,x,"r-*",label='sin') #绘制 sin 函数图像
plt.plot(t,y,"b-o",label='cos') #绘制 cos 函数图像
plt.plot(x,y,"g-.",label='sin+cos') #绘制 cos 函数图像
#将 x、y 两条曲线之间的的部分用 green 颜色填充
plt.fill_between(t, x, y, color='green', alpha=0.5) 
plt.axis("equal") #保证饼图是正圆，否则会有一点角度偏斜
plt.xlabel("x-横坐标") 
plt.ylabel("y-纵坐标") 
plt.title("三角函数") 
##显示图例
label=["sin",'cos','sin+cos'] 
plt.legend(label, loc='upper right') 
##保存图像
plt.savefig('./test2.jpg') #将图片保存在当前的目录下
